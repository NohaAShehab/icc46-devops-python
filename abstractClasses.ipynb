# %%
from abc import  ABC, abstractmethod
class Person(ABC):
    @abstractmethod
    def test(self):
        pass

p = Person() # Can't instantiate abstract class Person without an implementation for abstract method 'test'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       3     @abstractmethod
#       4     def test(self):
#       5         pass
# ----> 7 p = Person()
#
# TypeError: Can't instantiate abstract class Person without an implementation for abstract method 'test'
