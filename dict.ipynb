# %%
# represent information
info= [
    "noha", 33, "iti", "masters", "Egypt", "PHD Student", 5000
]

# %%
# keyword --> represent its nature
# sets ? --> don't allow duplication

"""
comma seperated key:value,

dict --> desn't allow key duplications

"""

# %%
d = {}
print(d,type(d))
# Out:
# {} <class 'dict'>

# %%
# dict is mutable datatype --> depends on keys - -> no duplication in keys

info  ={
    "name":"noha",
    "work" : "iti",
    "age": 33,
    "name": "Noha Shehab"
}
print(info)
# Out:
# {'name': 'Noha Shehab', 'work': 'iti', 'age': 33}

# %%
info["city"] = "Mansoura"
print(info)
# Out:
# {'name': 'Noha Shehab', 'work': 'iti', 'age': 33, 'city': 'Mansoura'}

# %%
info["work"]="Information Technology Institute"

# %%
print(info)
# Out:
# {'name': 'Noha Shehab', 'work': 'Information Technology Institute', 'age': 33, 'city': 'Mansoura'}

# %%
print(len(info))
# Out:
# 4

# %%
print(info.pop("name"))
print(info)
# Out:
# Noha Shehab
# {'work': 'Information Technology Institute', 'age': 33, 'city': 'Mansoura'}

# %%
track = "devops"

# %%
del track  # delete variable from memory

# %%
del info ["age"]

# %%
# extend dict ?
additionalInfo = {
    "courses": ["python", "linux","cloud"],
    "work": "iti"
}

info.update(additionalInfo)
print(info)
# Out:
# {'work': 'iti', 'city': 'Mansoura', 'courses': ['python', 'linux', 'cloud']}

# %%
# iterate over the dict
for item in info:
    print(f"item= {item}")
# Out:
# item= work
# item= city
# item= courses

# %%
for k, v in info:
    print(f"key= {k}, value = {v}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 for k, v in info:
#       2     print(f"key= {k}, value = {v}")
#
# ValueError: too many values to unpack (expected 2)

# %%
for k in info:
    print(k, info[k])
# Out:
# work iti
# city Mansoura
# courses ['python', 'linux', 'cloud']

# %%
# dict --> functions , get keys, values , items

keys = info.keys()
print(keys) # dict keys --> iterable ?
print(list(keys))
# Out:
# dict_keys(['work', 'city', 'courses'])
# ['work', 'city', 'courses']

# %%
values = info.values()
print(values)
print(list(values))
# Out:
# dict_values(['iti', 'Mansoura', ['python', 'linux', 'cloud']])
# ['iti', 'Mansoura', ['python', 'linux', 'cloud']]

# %%
# items ??
items = info.items() # dict_items
print(items)
# Out:
# dict_items([('work', 'iti'), ('city', 'Mansoura'), ('courses', ['python', 'linux', 'cloud'])])

# %%
items = list(items)

# %%
print('noha' in info.values())
# Out:
# False

# %%
info.clear()

# %%
ll = ["new", "abc", "test", 19]

# %%
del ll[2]

# %%
ll.clear()
