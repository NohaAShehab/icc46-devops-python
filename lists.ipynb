# %%
# define list
l = []
myl = list()

# %%
# list is mutable datatype ? can hold different data from datatypes
# you can change its content in the runtime ?
myl = ["Ahmed", "Hager", 34, 4.44, True , "iti",["jenkins", "docker", "microservice",None], "iti"]
#1- get len of ?

# %%
print(len(myl))
# Out:
# 8

# %%
# access elements using index start from 0 ??
print(myl[3])
print(myl[6][1])
# Out:
# 4.44
# docker

# %%
print(myl.count('iti'))
# Out:
# 2

# %%
print(myl[3:6])
# Out:
# [4.44, True, 'iti']

# %%
print(myl[::-1])
# Out:
# ['iti', ['jenkins', 'docker', 'microservice', None], 'iti', True, 4.44, 34, 'Hager', 'Ahmed']

# %%
# list is mutable datatype ==-(insert ,remove , append, pop,sort)

# append
myl.append("new element")
print(myl)
# Out:
# ['Ahmed', 'Hager', 34, 4.44, True, 'iti', ['jenkins', 'docker', 'microservice', None], 'iti', 'new element', 'new element']

# %%
# insert at certain position ??
myl.insert(3, "instered element")

# %%
myl.insert(100, 'new value') # append

# %%
# list is mutable datatype
# we need to update element at index  ??
myl[3]= "updated value"

# %%
myl[100]= "updated value" # ??
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 myl[100]= "updated value" # ??
#
# IndexError: list assignment index out of range

# %%
# concat 2 lists ??
basicCourses =['python', 'linux', 'db', 'os']
coreCourses = ['docker', 'openshift', 'jenkins', 'kubernate']
listOfCourse = basicCourses + coreCourses  #
print(listOfCourse)
# Out:
# ['python', 'linux', 'db', 'os', 'docker', 'openshift', 'jenkins', 'kubernate']

# %%
# extend list ?
basicCourses.extend(['oop', 'networks'])

# %%
# iterate over list ??
for item in myl:
    print(f"item ={item}")
# Out:
# item =Ahmed
# item =Hager
# item =34
# item =updated value
# item =4.44
# item =True
# item =iti
# item =['jenkins', 'docker', 'microservice', None]
# item =iti
# item =new element
# item =new element
# item =new value

# %%
# print item and its index??
for item in myl:
    print(f"item ={item}, {myl.index(item)}")
# Out:
# item =Ahmed, 0
# item =Hager, 1
# item =34, 2
# item =updated value, 3
# item =4.44, 4
# item =True, 5
# item =iti, 6
# item =['jenkins', 'docker', 'microservice', None], 7
# item =iti, 6
# item =new element, 9
# item =new element, 9
# item =new value, 11

# %%
counter = 0
for item in myl:
    print(f"item ={item}, {counter}")
    counter +=1
# Out:
# item =Ahmed, 0
# item =Hager, 1
# item =34, 2
# item =updated value, 3
# item =4.44, 4
# item =True, 5
# item =iti, 6
# item =['jenkins', 'docker', 'microservice', None], 7
# item =iti, 8
# item =new element, 9
# item =new element, 10
# item =new value, 11

# %%
myl_enum = enumerate(myl)
print(myl_enum)  # iterABLE OBJECT --> generate index for item?

# %%
print(list(myl_enum))
# Out:
# [(0, 'Ahmed'), (1, 'Hager'), (2, 34), (3, 'updated value'), (4, 4.44), (5, True), (6, 'iti'), (7, ['jenkins', 'docker', 'microservice', None]), (8, 'iti'), (9, 'new element'), (10, 'new element'), (11, 'new value')]

# %%
myl_enum = enumerate(myl)
for index, item in myl_enum:  # generate index of items
    print(f"{index}: {item}")
# Out:
# 0: Ahmed
# 1: Hager
# 2: 34
# 3: updated value
# 4: 4.44
# 5: True
# 6: iti
# 7: ['jenkins', 'docker', 'microservice', None]
# 8: iti
# 9: new element
# 10: new element
# 11: new value

# %%
# remove elements from list?
popped_element  = myl.pop()
print(popped_element)
print(myl)
# Out:
# new element
# ['Ahmed', 'Hager', 34, 'updated value', 4.44, True, 'iti', ['jenkins', 'docker', 'microservice', None], 'iti', 'new element']

# %%
popped_element  = myl.pop(4)
print(popped_element)
print(myl)
# Out:
# 4.44
# ['Ahmed', 'Hager', 34, 'updated value', True, 'iti', ['jenkins', 'docker', 'microservice', None], 'iti', 'new element']

# %%
# remove element --> "iti" --> without knowing its index ??
myl.remove("iti") # remove first occurence from list
print(myl)
# Out:
# ['Ahmed', 'Hager', 34, 'updated value', True, ['jenkins', 'docker', 'microservice', None], 'iti', 'new element']

# %%
# sort list ??  # list items from the same type
myl.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 2
#       1 # sort list ??
# ----> 2 myl.sort()
#
# TypeError: '<' not supported between instances of 'int' and 'str'

# %%
print(basicCourses)
basicCourses.sort()
print(basicCourses)
# Out:
# ['python', 'linux', 'db', 'os', 'oop', 'networks']
# ['db', 'linux', 'networks', 'oop', 'os', 'python']

# %%
print(coreCourses)
coreCourses.sort(reverse=True)
print(coreCourses)
# Out:
# ['docker', 'openshift', 'jenkins', 'kubernate']
# ['openshift', 'kubernate', 'jenkins', 'docker']

# %%
# reverse the list ?
print(myl)
myl.reverse()
print(myl)
# Out:
# ['Ahmed', 'Hager', 34, 'updated value', True, ['jenkins', 'docker', 'microservice', None], 'iti', 'new element']
# ['new element', 'iti', ['jenkins', 'docker', 'microservice', None], True, 'updated value', 34, 'Hager', 'Ahmed']

# %%
# check if element exists in list ??
print("iti" in myl)
# Out:
# True

# %%
# cast string to list ?
name= 'noha'
print(list(name))
# Out:
# ['n', 'o', 'h', 'a']

# %%
# join list elements to a string ===> all list elements must be string
info = ["noha", "iti", "devops"]
val = "-".join(info)
print(val)
# Out:
# noha-iti-devops

# %%
# convert string to a list
msg = 'we love python much'
print(msg.split(' '))
# Out:
# ['we', 'love', 'python', 'much']
