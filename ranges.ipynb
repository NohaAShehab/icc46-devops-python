# %%
# range one of the sequence based types ??

# %%
# range --> numbers only
myr = range(10)

# %%
# range object is iterable ??
for num in myr:
    print(f"num = {num}")
# Out:
# num = 0
# num = 1
# num = 2
# num = 3
# num = 4
# num = 5
# num = 6
# num = 7
# num = 8
# num = 9

# %%
myr = range(1, 10 , 2)
print(list(myr))
# Out:
# [1, 3, 5, 7, 9]

# %%
myr = range(1, 5,0.2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 myr = range(1, 5,0.2)
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
myr = range(.1, 15,2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 myr = range(.1, 15,2)
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
myr = range(1, 10, -1)
print(list(myr))
# Out:
# []

# %%
myr = range(20, 10, -1)
print(list(myr))
# Out:
# [20, 19, 18, 17, 16, 15, 14, 13, 12, 11]
