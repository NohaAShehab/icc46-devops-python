# %%
# sets ??
mys = {"Ahmed", "Ahmed", "noha", "Ali",34, 23.32, True, ("test", 10), 'Information Technology Institute'}

# %%
print(mys)
# Out:
# {True, 34, 'Information Technology Institute', 'noha', 'Ali', ('test', 10), 23.32, 'Ahmed'}

# %% [markdown]
# 1- remove duplicates
# 2- add data random without order
# 3- no index
# 4- use hashing in saving data

# %%
mys = {"Ahmed", "Ahmed", "noha", "Ali",34, 23.32, True, ("test", 10), 'Information Technology Institute', ["new item", 10 ]}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 mys = {"Ahmed", "Ahmed", "noha", "Ali",34, 23.32, True, ("test", 10), 'Information Technology Institute', ["new item", 10 ]}
#
# TypeError: unhashable type: 'list'

# %%
mys = {True, 34, 'Information Technology Institute', 'noha', 'Ali', ('test', 10), 23.32, 'Ahmed'}


# set mutable or immutable ?
# sets are mutable datatype
# add element , pop element ===> randomly

# %%
mys.add("new element")
print(mys)
# Out:
# {True, 34, 'new element', 'Information Technology Institute', 'noha', 'Ali', ('test', 10), 23.32, 'Ahmed'}

# %%
print(mys.pop()) # remove random
print(mys)
# Out:
# True
# {34, 'new element', 'Information Technology Institute', 'noha', 'Ali', ('test', 10), 23.32, 'Ahmed'}

# %%
print(len(mys))
# Out:
# 8
