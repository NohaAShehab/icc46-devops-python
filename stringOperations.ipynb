# %% [markdown]
# String

# %%
track = "DevOps track"

# %%
#1- get len of string
print(len(track))
# Out:
# 12

# %%
#2- access string using index start from 0
print(track[3])
# Out:
# O

# %%
# 3- get count of char D
print(track.count("D"))
# Out:
# 1

# %%
# 4- slicing the string
print(track[2:4])  # start index ,2 --> v ::
# Out:
# vO

# %%
print(track[2:6:1])  # start index ,2 --> v ::
# Out:
# vOps

# %%
print(track[3:9:2])  # start index ,2 --> v ::
# Out:
# Ost

# %%
print(track[::-1])  # any operation applied on the string -- return new string
# Out:
# kcart spOveD

# %%
# get index of char
org = "iti"
print(org.index("i")) # index return with first occurrance
# Out:
# 0

# %% [markdown]
# # String formatting

# %%
name = "noha abdelhady abdelhady shehab"
print(name.upper())
# Out:
# NOHA ABDELHADY ABDELHADY SHEHAB

# %%
print(name.lower())
# Out:
# noha abdelhady abdelhady shehab

# %%
print(name.capitalize())
# Out:
# Noha abdelhady abdelhady shehab

# %%
print(name.title())
# Out:
# Noha Abdelhady Abdelhady Shehab

# %% [markdown]
# # check this

# %%
fname = 'ahmed'
lname = 'ali'
fullname = fname + lname  # contact 2 strings using +
print(fullname)
# Out:
# ahmedali

# %%
no_of_students  = 20
desc = "we have" + no_of_students + "in this class "
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 2
#       1 no_of_students  = 20
# ----> 2 desc = "we have" + no_of_students + "in this class "
#
# TypeError: can only concatenate str (not "int") to str

# %%
no_of_students  = 20
desc = "we have " + str(no_of_students) + " in this class "
print(desc)
# Out:
# we have 20in this class

# %% [markdown]
# # format string according to template

# %%
# use format function
temp = "We have {0} student in this class, at {1}"

print(temp.format(20,2014))  # return new string

print(temp.format(200,"devops" ))
print(temp.format("devops",200))
# Out:
# We have 20 student in this class, at 2014
# We have 200 student in this class, at devops
# We have devops student in this class, at 200

# %%
# all the primitive datatypes are immutable
print(temp)
# Out:
# We have {0} student in this class, at {1}

# %%
temp = "We have {stdnum} student in this class, at {classname}"
print(temp.format(classname='devops', stdnum=34))  # use keyword identifier
# Out:
# We have 34 student in this class, at devops

# %%
# f-format string
# construct string based on existing variable ??
grade = 100
stname ='noha'
msg = f"student with name {stname} got grade = {grade}"
print(msg)
# Out:
# student with name noha got grade = 100

# %% [markdown]
# Examine string content ??

# %%
# ask user to enter number

# %%
age = input("please enter number : ")  # input return with string
print(age, type(age))
age = int(age)
print(f"entered value is {age}")
# Out:
# thirtyThree <class 'str'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 3
#       1 age = input("please enter number : ")  # input return with string
#       2 print(age, type(age))
# ----> 3 age = int(age)
#       4 print(f"entered value is {age}")
#
# ValueError: invalid literal for int() with base 10: 'thirtyThree'

# %%
# before casting  --> examine content of string ??
age = input("please enter age: ")
print(age.isdigit()) # retrun with true --> string consists only of number 0->9
print(age.isalpha()) # return true 0> string consists only of alpahs [a-z]
# Out:
# False
# True

# %%
# iteration over the string

for char in "iti":
    print(f"char = {char}")
# Out:
# char = i
# char = t
# char = i

# %%
# interpolation
fname = 'noha'
midname= 'abdelhady'
lname = 'shehab'

fullname = fname + midname + midname + lname

print(fullname)

fullname2 = fname + midname*2 + lname
print(fullname2)
# Out:
# nohaabdelhadyabdelhadyshehab
# nohaabdelhadyabdelhadyshehab

# %%
# replace
msg = "we love python very much o o "
# replace o --> @
print(msg.replace('o', '@')) # generate new string
# Out:
# we l@ve pyth@n very much @ @

# %%
print(msg.replace('o', '@', 3)) # generate new string
# Out:
# we l@ve pyth@n very much @ o

# %%
# strip string ??
username = "noha abdelhady"
username = "noha abdelhady "
# strip white spaces from string -from begining and end of string-
message= "      Hello world    "
print(message, len(message))
strippedmessage = message.strip()
print(strippedmessage, len(strippedmessage))
#  strip specific chars from beginning and the end of the string
# Out:
#       Hello world     21
# Hello world 11
